# %% [markdown]
# # 🍎 Fruit Image Analysis & Classification with Computer Vision and Machine Learning
#
# ### 📚 Overview
# This project combines **Image Processing**, **Data Analysis**, and **Machine Learning**
# to classify different types of fruits based on extracted visual features (color, shape, and texture).
#
# We use:
# - 🧠 **OpenCV** for feature extraction
# - 📊 **Pandas & Seaborn** for data analysis
# - 🌲 **Scikit-learn** for classification (Random Forest)
#
# ---

# %% [markdown]
# ## 🎯 Project Goal
# Build a system that can **analyze fruit images** and **classify them** using
# statistical features derived from image processing.
#
# Instead of using deep learning, this project focuses on:
# - Understanding how to extract meaningful features from images
# - Analyzing how those features correlate with fruit types
# - Building a traditional ML model for classification

# %% [markdown]
# ## 🧩 Project Architecture
#
# 1️⃣ **Feature Extraction (Computer Vision)**
#    - Load images
#    - Segment fruit from background
#    - Extract color, shape, and texture features
#
# 2️⃣ **Data Analysis**
#    - Explore feature distributions
#    - Visualize color and shape variations
#    - Study correlations between features
#
# 3️⃣ **Modeling (Machine Learning)**
#    - Train RandomForest classifier
#    - Evaluate with accuracy, F1-score, confusion matrix
#    - Analyze most important features

# %% [markdown]
# ## 📈 Results
#
# | Metric | Score |
# |:-------|:------:|
# | **Accuracy** | 97.36% |
# | **Best Features** | Mean Hue (H), Mean Saturation (S), Mean Value (V) |
#
# ✅ The model achieved **high accuracy** using only classical computer vision features,
# demonstrating that even without deep learning, feature engineering can effectively classify fruit types.
#
# ---

# %% [markdown]
# ## 🚀 Conclusions & Future Work
#
# **Conclusions:**
# - Color (Hue, Saturation) and shape (Circularity) were key discriminators among fruit types.
# - The dataset was diverse enough to train a solid baseline model.
# - Traditional ML models still perform strongly when features are well-designed.
#
# **Future Work:**
# - 🧩 Add a CNN (Deep Learning) model for comparison.
# - 📸 Include image quality metrics (sharpness, brightness).
# - 🌈 Deploy the model with a small web app using Streamlit or Flask.
#
# ---
